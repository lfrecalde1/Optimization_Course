# %% [markdown]
# <h1 align="center" style="font-size: 35px;"><font color="C1772D"><strong>Aplicación del Control Óptimo en el Campo de la Robótica</strong></font></h1>
#
# <h2 align="center"><font color="#667388"><strong>Luis F. Recalde</strong><br>Ambato-Ecuador</font></h2>
#
#
# <h3 align="center"><font color="#667388"><strong>Universidad Indoamerica</strong></font></h3>

# %% [markdown]
# <h3 style="font-size: 30px; color: #C1772D; font-weight: bold; text-align: left;">Optimizacion Minimizacion</h3>

# %% [markdown]
# <h3 align="left" style="font-size: 20px; color: #667388;"><strong>La Optimizacion con restricciones</strong></h3>

# %% [markdown]
# <div style="text-align: justify; font-size: 20px;">En esta sección se abordan problemas de optimización sujetos a restricciones de igualdad, lo cual puede ser escrito a continuación como:</div>

# %% [markdown]
# <span style="font-size:1.4em;">
# \begin{equation}
#     \begin{split}
#    \min_{\small \mathbf{x}}  \quad  f(\mathbf{x})\\
#     \textrm{subject to: } \\
#     \mathbf{c}(\mathbf{x}) = 0
#     \end{split}
#     \end{equation}
# </span>

# %% [markdown]
# <div style="text-align: justify; font-size: 20px;">
#    donde ${f}(\cdot): \mathbb{R}^{n} \rightarrow \mathbb{R}$ es conocida como la función de costo y $\mathbf{c}(\cdot): \mathbb{R}^{n} \rightarrow \mathbb{R}^{m} $
# </div>

# %% [markdown]
# <div style="text-align: justify; font-size: 20px;">Una vez formulado el problema, vamos a abordar los temas de condiciones necesarias de primer orden para resolver este tipo de problema de optimización.</div>

# %% [markdown]
# <h3 align="left" style="font-size: 20px;"><font color="#2D5AC1"><strong>Condiciones necesarias de primer Orden</strong></font></h3>

# %% [markdown]
# <div class="alert alert-block alert-success" style="font-size: 16px;">
#   <b>Nota:</b> $\nabla f(\mathbf{x}) = \mathbf{0}$ en cualquier direccion del problema
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success" style="font-size: 16px;">
#   <b>Nota:</b> $\mathbf{c} (\mathbf{x}) = \mathbf{0}$
# </div>

# %% [markdown]
# <div style="text-align: justify; font-size: 20px;">Por lo que se tendrá que hacer es tomar el gradiente y proyectarlo sobre las restricciones de igualdad.</div>

# %% [markdown]
# <div class="alert alert-block alert-success" style="font-size: 16px;">
#   <b>Nota:</b> Explicar en Pizarra.
# </div>

# %% [markdown]
# <div style="text-align: justify; font-size: 20px;">Por lo tanto, cualquier componente de \( \nabla f(\mathbf{x}) \) debe ser normal a la superficie o "manifold" de restricción $\mathbf{c}(\mathbf{x})$.</div>

# %% [markdown]
# <div style="text-align: justify; font-size: 20px;">Lo cual, en el caso unidimensional, puede ser escrito de la siguiente forma:</div>

# %% [markdown]
# <span style="font-size:1.4em;">
# \begin{equation}
#      \nabla f + \lambda \nabla c = 0, ~~~~~\lambda \in \mathbb{R}
#     \end{equation}
# </span>

# %% [markdown]
# <div style="text-align: justify; font-size: 20px;"> En el caso general esto puede ser escrito como:</div>

# %% [markdown]
# <span style="font-size:1.4em;">
# \begin{equation}
#     \frac{\partial {f}}{\partial \mathbf{x}} + \mathbf{\lambda}^{T} \frac{\partial {\mathbf{c}}}{\partial \mathbf{x}}  = 0, ~~~~~\lambda \in \mathbb{R}^{m}
#     \end{equation}
# </span>

# %% [markdown]
# <div style="text-align: justify; font-size: 20px;">Basado en las condiciones presentadas, es posible definir el siguiente lagrangiano, tal que:</div>

# %% [markdown]
# <span style="font-size:1.4em;">
# \begin{equation}
#      L(\mathbf{x}, \lambda) = f(\mathbf{x}) + \lambda^{T} \mathbf{c}(\mathbf{x})
#     \end{equation}
# </span>

# %% [markdown]
# <div style="text-align: justify; font-size: 20px;">Usando el gradiente respecto a $\mathbf{x}$ y $\lambda$, resulta en:</div>

# %% [markdown]
# <span style="font-size:1.4em;">
# \begin{equation}
#      \nabla_x L(\mathbf{x}, \lambda) = \nabla_x f(\mathbf{x}) + (\frac{\partial {\mathbf{c}}}{\partial \mathbf{x}})^{T} \lambda = \mathbf{0}
#     \end{equation}
# </span>

# %% [markdown]
# <span style="font-size:1.4em;">
# \begin{equation}
#      \nabla_{\lambda} L(\mathbf{x}, \lambda) = \mathbf{c}(\mathbf{x}) = \mathbf{0}
#     \end{equation}
# </span>

# %% [markdown]
# <div style="text-align: justify; font-size: 20px;">Estas expresiones se conocen como condiciones KKT, las cuales son condiciones necesarias de primer orden para problemas de optimización con restricciones.</div>

# %% [markdown]
# <h3 align="left" style="font-size: 20px;"><font color="#2D5AC1"><strong>Newton Method</strong></font></h3>

# %% [markdown]
# <div class="alert alert-block alert-success" style="font-size: 16px;">
#   <b>Nota:</b> No es sorpresa, pero podemos usar "Newton Method" para resolver este problema, usando la aproximación de Taylor resultando en:
# </div>

# %% [markdown]
# <span style="font-size:1.4em;">
# \begin{equation}
#      \nabla_x L(\mathbf{x} + \Delta \mathbf{x}, \lambda + \Delta \lambda) =\nabla_x L(\mathbf{x}, \lambda)  + \frac{\partial}{\partial\mathbf{x}}\nabla_x L(\mathbf{x}, \lambda)  \Delta \mathbf{x} + \frac{\partial}{\partial\mathbf{\lambda}}\nabla_x L(\mathbf{x}, \lambda)  \Delta \mathbf{\lambda}
#     \end{equation}
# </span>

# %% [markdown]
# <span style="font-size:1.4em;">
# \begin{equation}
#      \nabla_{\lambda} L(\mathbf{x} + \Delta \mathbf{x}, \lambda + \Delta \lambda) =\nabla_{\lambda} L(\mathbf{x}, \lambda)  + \frac{\partial}{\partial\mathbf{x}}\nabla_{\lambda} L(\mathbf{x}, \lambda)  \Delta \mathbf{x} + \frac{\partial}{\partial\mathbf{\lambda}}\nabla_{\lambda} L(\mathbf{x}, \lambda)  \Delta \mathbf{\lambda}
#     \end{equation}
# </span>

# %% [markdown]
# <div style="text-align: justify; font-size: 20px;">A continuación se presentan en detalle cada una de las derivadas parciales, tal que:</div>

# %% [markdown]
# <span style="font-size:1.4em;">
# \begin{equation}
#      \frac{\partial}{\partial\mathbf{x}}\nabla_x L(\mathbf{x}, \lambda) = \frac{\partial}{\partial\mathbf{x}} \nabla_x f(\mathbf{x}) + \frac{\partial}{\partial\mathbf{x}}  (\frac{\partial {\mathbf{c}}}{\partial \mathbf{x}})^{T} \lambda
#     \end{equation}
# </span>

# %% [markdown]
# <span style="font-size:1.4em;">
# \begin{equation}
# \frac{\partial}{\partial\mathbf{\lambda}}\nabla_x L(\mathbf{x}, \lambda) = (\frac{\partial {\mathbf{c}}}{\partial \mathbf{x}})^{T}
#     \end{equation}
# </span>

# %% [markdown]
# <span style="font-size:1.4em;">
# \begin{equation}
#      \frac{\partial}{\partial\mathbf{x}}\nabla_{\lambda} L(\mathbf{x}, \lambda)  = \frac{\partial}{\partial\mathbf{x}}  \mathbf{c}(\mathbf{x})
#     \end{equation}
# </span>

# %% [markdown]
# <span style="font-size:1.4em;">
# \begin{equation}
#      \frac{\partial}{\partial\mathbf{\lambda}}\nabla_{\lambda} L(\mathbf{x}, \lambda)  = \mathbf{0}
#     \end{equation}
# </span>

# %% [markdown]
# <div style="text-align: justify; font-size: 20px;">Reemplazando en la aproximación de Taylor e igualando a cero, se obtiene la siguiente expresión:</div>

# %% [markdown]
# <span style="font-size:1.4em;">
# \begin{equation}
#     \nabla_x L(\mathbf{x}, \lambda)  + (\frac{\partial}{\partial\mathbf{x}} \nabla_x f(\mathbf{x}) + \frac{\partial}{\partial\mathbf{x}}  ((\frac{\partial {\mathbf{c}}}{\partial \mathbf{x}})^{T} \lambda)  \Delta \mathbf{x} + (\frac{\partial {\mathbf{c}}}{\partial \mathbf{x}}^{T}) \Delta \mathbf{\lambda} = \mathbf{0}
#     \end{equation}
# </span>

# %% [markdown]
# <span style="font-size:1.4em;">
# \begin{equation}
#       \mathbf{c}(\mathbf{x}) + \frac{\partial}{\partial\mathbf{x}}  \mathbf{c}(\mathbf{x})  \Delta \mathbf{x} = \mathbf{0}
#     \end{equation}
# </span>

# %% [markdown]
# <div style="text-align: justify; font-size: 20px;">Este sistema de ecuaciones puede ser expresado de forma compacta, como se presenta a continuación:</div>

# %% [markdown]
# <span style="font-size:1.4em;">
# \begin{equation}
#       \begin{bmatrix} \frac{\partial}{\partial\mathbf{x}} \nabla_x f(\mathbf{x}) + \frac{\partial}{\partial\mathbf{x}}  (\frac{\partial {\mathbf{c}}}{\partial \mathbf{x}}^{T} \lambda) &\frac{\partial {\mathbf{c}}}{\partial \mathbf{x}}^{T} \\ \frac{\partial \mathbf{c}}{\partial\mathbf{x}}   & \mathbf{0} \end{bmatrix} \begin{bmatrix} \Delta \mathbf{x} \\ \Delta \mathbf{\lambda} \end{bmatrix} = -\begin{bmatrix} \nabla_x L(\mathbf{x}, \lambda) \\  \mathbf{c}(\mathbf{x})\end{bmatrix}
#     \end{equation}
# </span>

# %% [markdown]
# <div style="text-align: justify; font-size: 20px;">Este tipo de representacion se la conoce como "KKT System"</div>

# %% [markdown]
# <div style="text-align: justify; font-size: 20px;">Este algoritmo representacion es mu util al momento de utilizar "Newton Method", debido a que se puede resolver el sistema para $\Delta\mathbf{x}$ y $\Delta\mathbf{\lambda}$</div>

# %% [markdown]
# <h3 align="left" style="font-size: 20px;"><font color="#2D5AC1"><strong>Gauss Newton Method</strong></font></h3>

# %% [markdown]
# <div style="text-align: justify; font-size: 20px;">Analizar el elemento $(1, 1)$ de la matriz "KKT". A continuación, se representa este elemento:</div>

# %% [markdown]
# <span style="font-size:1.4em;">
# \begin{equation}
#      \frac{\partial}{\partial\mathbf{x}}\nabla_x L(\mathbf{x}, \lambda) = \frac{\partial}{\partial\mathbf{x}} \nabla_x f(\mathbf{x}) + \frac{\partial}{\partial\mathbf{x}}  (\frac{\partial {\mathbf{c}}}{\partial \mathbf{x}})^{T} \lambda
#     \end{equation}
# </span>

# %% [markdown]
# <div style="text-align: justify; font-size: 20px;">El último elemento de esta expresión puede considerarse como un tensor de orden $3$ y, en general, es lo más costoso de computar y molesto. Sin embargo, si utilizamos herramientas de diferenciación automática, este término no tiene costo y puede ser computado fácilmente, aunque se deben tomar ciertas precauciones.</div>

# %% [markdown]
# <div class="alert alert-block alert-success" style="font-size: 16px;">
#   <b>Nota:</b> Si se quiere codificar esta expresión a mano, es mejor omitir el último elemento.
# </div>

# %% [markdown]
# <div style="text-align: justify; font-size: 20px;">Por lo que históricamente, si no se considera este elemento, el algoritmo de "Newton" toma el nombre de "Gauss-Newton".</div>

# %% [markdown]
# <div class="alert alert-block alert-success" style="font-size: 16px;">
#   <b>Nota:</b> "Gauss newton" es ligeramente mas lento que "Newton"
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success" style="font-size: 16px;">
#   <b>Code:</b> Optimization sin restricciones
# </div>

# %%
from IPython.display import HTML
from IPython.display import display, Image
import casadi as ca
from casadi import jacobian
from casadi import gradient
from casadi import Function
from casadi import vertcat
import numpy as np
from numpy import linalg as LA
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Definir la funcion costo sin restricciones

# %%
def f_casadi():
    # Cost function to minimize 
    # INPUTS
    # x                                                - optimization variables
    # OUTPUT
    # r                                                - cost values
    # dfdx                                             - partial derivative respect to x
    x =  ca.MX.sym('x', 2, 1)
    Q = ca.diag([0.5, 1.0])
    xd = ca.MX([1.0, 0.0])
    xe = x-xd
    # Cost function
    f_sym = (1/2)*xe.T@Q@xe
    f = Function('f',[x], [f_sym])

    # Jacobian of the cost
    df_dx_sym = gradient(f_sym, x)
    df_dx = Function('df_dx', [x], [df_dx_sym])

    # hessian of the cost
    d2f_d2x_sym = jacobian(df_dx_sym, x)
    d2f_d2x = Function('d2d_d2x', [x], [d2f_d2x_sym])
    
    return f, df_dx, d2f_d2x

# %% [markdown]
# ### Verificar funciones

# %%
# Init Values
x  = np.array([0.1, 0])

# Generate functions
f, df_dx, d2f_d2x = f_casadi()

# Call functions
r =  f(x)
df = df_dx(x)
H = d2f_d2x(x)

# Print values
print(r)
print(df)
print(H)
# Out:
# 0.2025
# [-0.45, 0]
#
# [[0.5, 00],
#  [00, 1]]

# %% [markdown]
# ### Graficar costo

# %%
xlist = np.linspace(-5.0, 5.0, 100)
ylist = np.linspace(-5.0, 5.0, 100)
X, Y = np.meshgrid(xlist, ylist)
Z = np.array([[f(np.array([x_val, y_val])) for x_val, y_val in zip(x_row, y_row)] for x_row, y_row in zip(X, Y)])
Z = Z.reshape((Z.shape[0], Z.shape[1]))
print(Z.shape)
plt.contour(X, Y, Z, levels=30)  
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Function Costo')
plt.colorbar(label='Valor funcion Costo')
plt.grid(True)
plt.show()
# Out:
# (100, 100)

# %%
def newton_step(x0, f, dfdx, d2fd2x):
    # Newton algorithm n dimensional case
    # INPUTS
    # x0                                   - x0 initial guess
    # f                                    - residual cost function
    # dfdx                                 - gradient of the residual
    # d2fd2x                               - hessian of the residual
    # OUTPUTS
    # xn                                   - new value of the guess
    # Compute Values
    H = d2fd2x(x0)
    grad = dfdx(x0)
    delta = - LA.inv(H)@grad
    xn = x0 + 1*delta
    return xn

# %% [markdown]
# ### Verificar algoritmo de newton

# %%
# Initial values
xguess = np.array([-4, -4])
f_guess = f(xguess)
plt.contour(X, Y, Z, levels=30)  
plt.plot(xguess[0],xguess[1], '*b')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Function Costo')
plt.colorbar(label='Valor funcion Costo')
plt.grid(True)


# Update values based on Newton
# 1st Update
xguess = newton_step(xguess, f, df_dx, d2f_d2x)
plt.plot(xguess[0],xguess[1], '*r')

# 2nd update
#xguess = newton_step(xguess, f, df_dx, d2f_d2x)
#plt.plot(xguess[0],xguess[1], '*y')

# 3rd update
#xguess = newton_step(xguess, f, df_dx, d2f_d2x)
#plt.plot(xguess[0],xguess[1], '*')

#plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success" style="font-size: 16px;">
#   <b>Code:</b> Optimization con restricciones
# </div>

# %% [markdown]
# ### Definir la funcion costo con restricciones

# %%
def f_casadi_res():
    # Cost function to minimize 
    # INPUTS
    # x                                                - optimization variables
    # OUTPUT
    # r                                                - cost values
    # dfdx                                             - partial derivative respect to x
    x =  ca.MX.sym('x', 2, 1)
    Q = ca.diag([0.5, 1.0])
    xd = ca.MX([1.0, 0.0])
    xe = x-xd
    lambda_ = ca.MX.sym('lambda_', 1, 1)
    # Cost function
    f_sym = (1/2)*xe.T@Q@xe
    f = Function('f',[x], [f_sym])

    # Jacobian of the cost
    df_dx_sym = gradient(f_sym, x)
    df_dx = Function('df_dx', [x], [df_dx_sym])

    # hessian of the cost
    d2f_d2x_sym = jacobian(df_dx_sym, x)
    d2f_d2x = Function('d2d_d2x', [x], [d2f_d2x_sym])

    ## Constraints of the problem
    c_sym = x[0, 0]**2 + 2*x[0, 0] -x[1, 0]
    c = Function('c',[x], [c_sym])

    grad_x_c_sym = gradient(c_sym, x)
    grad_x_c = Function('grad_x_c', [x], [grad_x_c_sym])

    dx_grad_x_c_sym = jacobian(grad_x_c_sym@lambda_, x)
    dx_grad_x_c = Function('dx_grad_x_c', [x, lambda_], [dx_grad_x_c_sym])
    
    return f, df_dx, d2f_d2x, c, grad_x_c, dx_grad_x_c

# %% [markdown]
# ### Verificar Funciones

# %%
# Init Values
x  = np.array([0.1, 0])

# Generate functions
f, df_dx, d2f_d2x, c, grad_x_c, dx_grad_x_c = f_casadi_res()

# Call functions
r =  f(x)
print(r)
df = df_dx(x)
print(df)
H = d2f_d2x(x)
print(H)
const = c(x)
print(const)
grad_c = grad_x_c(x)
print(grad_c)
dx_grad_c = dx_grad_x_c(xguess, 0)
print(dx_grad_c)
# Out:
# 0.2025
# [-0.45, 0]
#
# [[0.5, 00],
#  [00, 1]]
# 0.21
# [2.2, -1]
#
# [[0, 00],
#  [00, 00]]

# %% [markdown]
# ### Figuras

# %%
xlist = np.linspace(-5.0, 5.0, 100)
ylist = np.linspace(-5.0, 5.0, 100)
xlist_rest = np.linspace(-3.2, 1.2, 100)
X, Y = np.meshgrid(xlist, ylist)
Z = np.array([[f(np.array([x_val, y_val])) for x_val, y_val in zip(x_row, y_row)] for x_row, y_row in zip(X, Y)])
Z = Z.reshape((Z.shape[0], Z.shape[1]))
plt.contour(X, Y, Z, levels=30) 
plt.plot(xlist_rest, xlist_rest**2 + 2.0*xlist_rest, '-')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Function Costo')
plt.colorbar(label='Valor funcion Costo')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Newton method Constraints

# %%
def newton_step_constraint(x0, lambda_0, f, dfdx, d2fd2x, f_c, grad_c, dx_grad_c):
    # Newton algorithm n dimensional case
    # INPUTS
    # x0                                   - x0 initial guess
    # f                                    - residual cost function
    # dfdx                                 - gradient of the residual
    # d2fd2x                               - hessian of the residual
    # OUTPUTS
    # xn                                   - new value of the guess
    # Compute Values
    H_x = d2fd2x(x0) 
    grad_f_x = dfdx(x0)
    grad_c_x = grad_c(x0)

    grad_L = grad_f_x + grad_c_x*lambda_0
    c = f_c(x0)

    H = np.zeros((3, 3))
    H[0:2, 0:2] = H_x
    #H[0:2, 0:2] = H_x + dx_grad_c(x0, lambda_0)
    H[0, 2] = grad_c_x[0, 0]
    H[1, 2] = grad_c_x[1, 0]
    H[2, 0] = grad_c_x.T[0, 0]
    H[2, 1] = grad_c_x.T[0, 1]
    H[2, 2] = 0.0

    gradient = np.zeros((3, 1))
    gradient[0, 0] = grad_L[0, 0]
    gradient[1, 0] = grad_L[1, 0]
    gradient[2, 0] = c

    delta = -LA.inv(H)@gradient
    xn = x0 + delta[0:2].reshape((2, ))
    lambda_n = lambda_0 + delta[2].reshape((1, ))
    return xn, lambda_n

# %% [markdown]
# <span style="font-size:1.4em;">
# \begin{equation}
#      \nabla_x L(\mathbf{x}, \lambda) = \nabla_x f(\mathbf{x}) + (\frac{\partial {\mathbf{c}}}{\partial \mathbf{x}})^{T} \lambda = \mathbf{0}
#     \end{equation}
# </span>

# %% [markdown]
# <span style="font-size:1.4em;">
# \begin{equation}
#       \begin{bmatrix} \frac{\partial}{\partial\mathbf{x}} \nabla_x f(\mathbf{x}) + \frac{\partial}{\partial\mathbf{x}}  (\frac{\partial {\mathbf{c}}}{\partial \mathbf{x}}^{T} \lambda) &\frac{\partial {\mathbf{c}}}{\partial \mathbf{x}}^{T} \\ \frac{\partial \mathbf{c}}{\partial\mathbf{x}}   & \mathbf{0} \end{bmatrix} \begin{bmatrix} \Delta \mathbf{x} \\ \Delta \mathbf{\lambda} \end{bmatrix} = -\begin{bmatrix} \nabla_x L(\mathbf{x}, \lambda) \\  \mathbf{c}(\mathbf{x})\end{bmatrix}
#     \end{equation}
# </span>

# %%
xguess = np.array([-3, 1])
lambda_guess = np.array([0.0])
f_guess = f(xguess)

plt.contour(X, Y, Z, levels=30) 
plt.plot(xlist_rest, xlist_rest**2 + 2.0*xlist_rest, '-')
plt.plot(xguess[0],xguess[1], '*')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Function Costo')
plt.colorbar(label='Valor funcion Costo')
plt.grid(True)

# 1st Update
xguess, lambda_guess = newton_step_constraint(xguess, lambda_guess, f, df_dx, d2f_d2x, c, grad_x_c, dx_grad_x_c)
plt.plot(xguess[0],xguess[1], '*')

# # 2nd Update
xguess, lambda_guess = newton_step_constraint(xguess, lambda_guess, f, df_dx, d2f_d2x, c, grad_x_c, dx_grad_x_c)
plt.plot(xguess[0],xguess[1], '*')

# # 3rd Update
xguess, lambda_guess = newton_step_constraint(xguess, lambda_guess, f, df_dx, d2f_d2x, c, grad_x_c, dx_grad_x_c)
plt.plot(xguess[0],xguess[1], '*')

# # 5th Update
xguess, lambda_guess = newton_step_constraint(xguess, lambda_guess, f, df_dx, d2f_d2x, c, grad_x_c, dx_grad_x_c)
plt.plot(xguess[0],xguess[1], '*')

# # 6th Update
xguess, lambda_guess = newton_step_constraint(xguess, lambda_guess, f, df_dx, d2f_d2x, c, grad_x_c, dx_grad_x_c)
plt.plot(xguess[0],xguess[1], '*')

# 7th Update
xguess, lambda_guess = newton_step_constraint(xguess, lambda_guess, f, df_dx, d2f_d2x, c, grad_x_c, dx_grad_x_c)
plt.plot(xguess[0],xguess[1], '*')

# 8th Update
xguess, lambda_guess = newton_step_constraint(xguess, lambda_guess, f, df_dx, d2f_d2x, c, grad_x_c, dx_grad_x_c)
plt.plot(xguess[0],xguess[1], '*')

#print(xguess, lambda_guess)

# %% [markdown]
# ### Verificar los valores obtenidos

# %%
f_guess = f(xguess)
print(f_guess)
# Out:
# 0.224536

# %%
c_guess = c(xguess)
print(c_guess)
# Out:
# 8.55179e-06

# %%
 L = f(xguess) + lambda_guess*c(xguess)
print(L)
# Out:
# 0.224538

# %% [markdown]
# <div class="alert alert-block alert-success" style="font-size: 16px;">
#   <b>Nota:</b> Analizar "Newton" y "Gauss-Newton"
# </div>

# %%
H = d2f_d2x(xguess) 
print(H)
# Out:
# [[0.5, 00],
#  [00, 1]]

# %% [markdown]
# <div class="alert alert-block alert-success" style="font-size: 16px;">
#   <b>Nota:</b> Podemos concluir que, sin importar que la función de costo sea convexa, debemos regularizar el problema o utilizar directamente el método de Gauss-Newton, el cual es muy usado en la práctica.
# </div>

# %%
def f_casadi_res_quadratic():
    # Cost function to minimize 
    # INPUTS
    # x                                                - optimization variables
    # OUTPUT
    # r                                                - cost values
    # dfdx                                             - partial derivative respect to x
    x =  ca.MX.sym('x', 2, 1)
    Q = ca.diag([2, 2])
    xd = ca.MX([0.0, 0.0])
    xe = x-xd
    lambda_ = ca.MX.sym('lambda_', 1, 1)
    # Cost function
    f_sym = xe.T@Q@xe
    f = Function('f',[x], [f_sym])

    # Jacobian of the cost
    df_dx_sym = gradient(f_sym, x)
    df_dx = Function('df_dx', [x], [df_dx_sym])

    # hessian of the cost
    d2f_d2x_sym = jacobian(df_dx_sym, x)
    d2f_d2x = Function('d2d_d2x', [x], [d2f_d2x_sym])

    ## Constraints of the problem
    c_sym = x[0, 0] - x[1, 0]  +1.5
    c = Function('c',[x], [c_sym])

    grad_x_c_sym = gradient(c_sym, x)
    grad_x_c = Function('grad_x_c', [x], [grad_x_c_sym])

    dx_grad_x_c_sym = jacobian(grad_x_c_sym@lambda_, x)
    dx_grad_x_c = Function('dx_grad_x_c', [x, lambda_], [dx_grad_x_c_sym])
    
    return f, df_dx, d2f_d2x, c, grad_x_c, dx_grad_x_c

# %% [markdown]
# <div style="text-align: justify; font-size: 20px;"> Verificar funcion</div>

# %%
# Init Values
x  = np.array([0.1, 0])

# Generate functions
f, df_dx, d2f_d2x, c, grad_x_c, dx_grad_x_c = f_casadi_res_quadratic()

# Call functions
r =  f(x)
df = df_dx(x)
H = d2f_d2x(x)
const = c(x)
grad_c = grad_x_c(x)
dx_grad_c = dx_grad_x_c(xguess, 0)

# %% [markdown]
# <div style="text-align: justify; font-size: 20px;"> Graficas.</div>

# %%
xlist = np.linspace(-5.0, 5.0, 100)
ylist = np.linspace(-5.0, 5.0, 100)
xlist_rest = np.linspace(-3.2, 3.2, 100)
X, Y = np.meshgrid(xlist, ylist)
Z = np.array([[f(np.array([x_val, y_val])) for x_val, y_val in zip(x_row, y_row)] for x_row, y_row in zip(X, Y)])
Z = Z.reshape((Z.shape[0], Z.shape[1]))
plt.contour(X, Y, Z, levels=30) 
plt.plot(xlist_rest, xlist_rest+1.5, '-')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Function Costo')
plt.colorbar(label='Valor funcion Costo')
plt.grid(True)
plt.show()

# %%
xguess = np.array([-4, 0])
lambda_guess = np.array([0.0])
f_guess = f(xguess)

plt.contour(X, Y, Z, levels=30) 
plt.plot(xlist_rest, xlist_rest+1.5, '-')
plt.plot(xguess[0],xguess[1], '*')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Function Costo')
plt.colorbar(label='Valor funcion Costo')
plt.grid(True)

# 1st Update
xguess, lambda_guess = newton_step_constraint(xguess, lambda_guess, f, df_dx, d2f_d2x, c, grad_x_c, dx_grad_x_c)
plt.plot(xguess[0],xguess[1], '*')

# # 2nd Update
#xguess, lambda_guess = newton_step_constraint(xguess, lambda_guess, f, df_dx, d2f_d2x, c, grad_x_c, dx_grad_x_c)
#plt.plot(xguess[0],xguess[1], '*')

# # 3rd Update
#xguess, lambda_guess = newton_step_constraint(xguess, lambda_guess, f, df_dx, d2f_d2x, c, grad_x_c, dx_grad_x_c)
#plt.plot(xguess[0],xguess[1], '*')

# # 5th Update
#xguess, lambda_guess = newton_step_constraint(xguess, lambda_guess, f, df_dx, d2f_d2x, c, grad_x_c, dx_grad_x_c)
#plt.plot(xguess[0],xguess[1], '*')

# # 6th Update
#xguess, lambda_guess = newton_step_constraint(xguess, lambda_guess, f, df_dx, d2f_d2x, c, grad_x_c, dx_grad_x_c)
#plt.plot(xguess[0],xguess[1], '*')

# 7th Update
#xguess, lambda_guess = newton_step_constraint(xguess, lambda_guess, f, df_dx, d2f_d2x, c, grad_x_c, dx_grad_x_c)
#plt.plot(xguess[0],xguess[1], '*')

# 8th Update
#xguess, lambda_guess = newton_step_constraint(xguess, lambda_guess, f, df_dx, d2f_d2x, c, grad_x_c, dx_grad_x_c)
#plt.plot(xguess[0],xguess[1], '*')

print(xguess, lambda_guess)
# Out:
# [-0.75  0.75] [3.]
